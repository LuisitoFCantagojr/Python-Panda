# %%
import pandas as pd

Excel1 = 'Historical Report - January.xlsm'
Excel2 = 'Historical Report - February.xlsm'
Excel3 = 'Historical Report - March.xlsm' 
Excel4 = 'Historical Report - April.xlsm'
Excel5 = 'Historical Report - May.xlsm'
Excel6 = 'Historical Report - June.xlsm'
Excel7 = 'Historical Report - July.xlsm'
Excel8 = 'Historical Report - August.xlsm'
Excel9 = 'Historical Report - September.xlsm'
Excel10 = 'Historical Report - October.xlsm'
Excel11 = 'Historical Report - November.xlsm'
Excel12 = 'Historical Report - December.xlsm'


df1 = pd.read_excel (Excel1,sheet_name='Cleaned')
df2 = pd.read_excel (Excel2,sheet_name='Cleaned')
df3 = pd.read_excel (Excel3,sheet_name='Cleaned')
df4 = pd.read_excel (Excel4,sheet_name='Cleaned')
df5 = pd.read_excel (Excel5,sheet_name='Cleaned')
df6 = pd.read_excel (Excel6,sheet_name='Cleaned')
df7 = pd.read_excel (Excel7,sheet_name='Cleaned')
df8 = pd.read_excel (Excel8,sheet_name='Cleaned')
df9 = pd.read_excel (Excel9,sheet_name='Cleaned')
df10 = pd.read_excel (Excel10,sheet_name='Cleaned')
df11 = pd.read_excel (Excel11,sheet_name='Cleaned')
df12 = pd.read_excel (Excel12,sheet_name='Cleaned')

print (df1) 
print (df2)

Value1 = df1[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value2 = df2[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value3 = df3[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value4 = df4[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value5 = df5[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value6 = df6[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value7 = df7[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value8 = df8[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value9 = df9[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value10 = df10[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value11 = df11[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]
Value12 = df12[['Trend','Date','OHR','Name','Unit Manager','Operation Manager','Portfolio','Availability','Productivity','Actual RABS']]


Dataframes = [Value1, Value2,Value3,Value4,Value5,Value6,Value7,Value8,Value9,Value10,Value11,Value12]
join = pd.concat(Dataframes)
join.to_excel("ConsolidatedFile.xlsx")
# Out:
#       Trend       Date        OHR               Name       Unit Manager  \
# 0   January 2021-01-01  740018760       George Mason  Margaret Cayabyab
# 1   January 2021-01-02  740018760          Sam Quinn     Mathew Salazar
# 2   January 2021-01-03  740018760  Jennifer Lawrence  Margaret Cayabyab
# 3   January 2021-01-04  740018760          Matt Acer          Joy Giron
# 4   January 2021-01-05  740018760  Jennifer Lawrence     Mathew Salazar
# 5   January 2021-01-06  740018760          Sam Quinn       Emily Carson
# 6   January 2021-01-07  740018760       George Mason       Emily Carson
# 7   January 2021-01-08  740018760       George Mason  Margaret Cayabyab
# 8   January 2021-01-09  740018760          Sam Quinn  Margaret Cayabyab
# 9   January 2021-01-10  740018760          Sam Quinn     Jesslyn Mendez
# 10  January 2021-01-11  740018760       George Mason       Emily Carson
# 11  January 2021-01-12  740018760  Jennifer Lawrence     Jesslyn Mendez
# ...
